# %%
from google.colab import drive
drive.mount('/content/drive')
DRIVE_PATH = '/content/drive/MyDrive/Colab Notebooks/fraud-project/'
print("Connected!")
# Out:
# Mounted at /content/drive
# Connected!

# %%
import os

REPO = '/content/fraud-detection-ieee/'

folders = [
    'data',
    'models',
    'notebooks',
    'reports',
    'src',
    'tests',
    '.github'
]

for folder in folders:
    os.makedirs(REPO + folder, exist_ok=True)
    print(f"Created: {folder}/")

print("\nAll folders created!")
# Out:
# Created: data/
# Created: models/
# Created: notebooks/
# Created: reports/
# Created: src/
# Created: tests/
# Created: .github/
#
# All folders created!
